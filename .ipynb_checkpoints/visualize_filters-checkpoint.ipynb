# %%
import numpy as np
import pandas as pd
import time
#import fma
import os
#import librosa
import scipy
import tensorflow as tf
#from tqdm import tqdm
import multiprocessing
from sklearn.utils import shuffle
from sklearn.metrics import log_loss

from sklearn.preprocessing import OneHotEncoder

import keras
from keras.models import Sequential
from keras.models import Model, load_model
from keras.layers import Dense, Dropout, Flatten, BatchNormalization, Input, Embedding, LSTM, GRU
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Bidirectional, Lambda
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard
from keras import backend as K
from keras.utils import to_categorical

from sklearn.utils import shuffle
#from sklearn.preprocessing import normalize

import argparse

#tf.enable_eager_execution()
# Out:
# Using TensorFlow backend.

# %%
def normalize(x):
    # utility function to normalize a tensor by its L2 norm
    return x / (K.sqrt(K.mean(K.square(x))) + K.epsilon())


def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + K.epsilon())
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    if K.image_data_format() == 'channels_first':
        x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
model = load_model('./best_psy_cnn.h5')

# %%
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
layer_dict
# Out:
# {'input_1': <keras.engine.input_layer.InputLayer at 0x7f6278c73160>,
#  'batch_normalization_1': <keras.layers.normalization.BatchNormalization at 0x7f6278c73358>,
#  'conv2d_1': <keras.layers.convolutional.Conv2D at 0x7f6278c73b70>,
#  'conv2d_2': <keras.layers.convolutional.Conv2D at 0x7f6278c73f60>,
#  'conv2d_3': <keras.layers.convolutional.Conv2D at 0x7f60709e8128>,
#  'conv2d_4': <keras.layers.convolutional.Conv2D at 0x7f60709e8208>,
#  'conv2d_5': <keras.layers.convolutional.Conv2D at 0x7f60709e83c8>,
#  'concatenate_1': <keras.layers.merge.Concatenate at 0x7f60709e84a8>,
#  'concatenate_2': <keras.layers.merge.Concatenate at 0x7f60709e8550>,
#  'average_pooling2d_1': <keras.layers.pooling.AveragePooling2D at 0x7f60709e8630>,
#  'max_pooling2d_1': <keras.layers.pooling.MaxPooling2D at 0x7f60709e8780>,
#  'concatenate_3': <keras.layers.merge.Concatenate at 0x7f60709e86d8>,
#  'dropout_1': <keras.layers.core.Dropout at 0x7f60709e8668>,
#  'dropout_2': <keras.layers.core.Dropout at 0x7f60709e87f0>,
#  'flatten_1': <keras.layers.core.Flatten at 0x7f60709e8828>,
#  'dense_1': <keras.layers.core.Dense at 0x7f60709e8908>,
#  'dropout_3': <keras.layers.core.Dropout at 0x7f60709e85c0>,
#  'dense_2': <keras.layers.core.Dense at 0x7f60709e8978>,
#  'dropout_4': <keras.layers.core.Dropout at 0x7f60709e8ac8>,
#  'dense_3': <keras.layers.core.Dense at 0x7f60709e8b38>}

# %%
# thanks to https://github.com/keras-team/keras/blob/master/examples/conv_filter_visualization.py

# dimensions of the generated pictures for each filter.
img_width = 128
img_height = 128

# name the convolutional layer to be visualized  
layer_name = 'conv2d_3'
input_img = model.input

# %%
# the following produces visualizations of the most activated filters in a convolutional
# layer
kept_filters = []
for filter_index in range(200):
    # we only scan through the first 200 filters,
    # but there are actually 512 of them
    print('Processing filter %d' % filter_index)
    start_time = time.time()

    # we build a loss function that maximizes the activation
    # of the nth filter of the layer considered
    layer_output = layer_dict[layer_name].output
    if K.image_data_format() == 'channels_first':
        loss = K.mean(layer_output[:, filter_index, :, :])
    else:
        loss = K.mean(layer_output[:, :, :, filter_index])

    # we compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads = normalize(grads)

    # this function returns the loss and grads given the input picture
    iterate = K.function([input_img], [loss, grads])

    # step size for gradient ascent
    step = 1.

    # we start from a gray image with some random noise
    if K.image_data_format() == 'channels_first':
        input_img_data = np.random.random((1, 1, img_width, img_height))
    else:
        input_img_data = np.random.random((1, img_width, img_height, 1))
    input_img_data = (input_img_data - 0.5) * 20 + 128

    # we run gradient ascent for 20 steps
    for i in range(20):
        loss_value, grads_value = iterate([input_img_data])
        input_img_data += grads_value * step

        print('Current loss value:', loss_value)
        if loss_value <= 0.:
            # some filters get stuck to 0, we can skip them
            break

    # decode the resulting input image
    if loss_value > 0:
        img = deprocess_image(input_img_data[0])
        kept_filters.append((img, loss_value))
    end_time = time.time()
    print('Filter %d processed in %ds' % (filter_index, end_time - start_time))
# Out:
# Processing filter 0
# Current loss value: 21.615595
# Current loss value: 29.022652
# Current loss value: 29.531164
# Current loss value: 30.430878
# Current loss value: 31.49479
# Current loss value: 32.945225
# Current loss value: 34.959557
# Current loss value: 37.396835
# Current loss value: 40.181816
# Current loss value: 43.457718
# Current loss value: 46.88842
# Current loss value: 50.48059
# Current loss value: 54.6373
# Current loss value: 58.88044
# Current loss value: 63.147957
# Current loss value: 67.49219
# Current loss value: 72.11617
# Current loss value: 76.90109
# Current loss value: 81.7232
# Current loss value: 86.5908
# Filter 0 processed in 1s
# Processing filter 1
# Current loss value: 40.511833
# Current loss value: 50.37003
# Current loss value: 51.88451
# Current loss value: 53.500984
# Current loss value: 54.989998
# Current loss value: 56.4154
# Current loss value: 57.796387
# Current loss value: 59.178844
# Current loss value: 60.449642
# Current loss value: 61.114
# Current loss value: 61.950203
# Current loss value: 62.850365
# Current loss value: 63.59341
# Current loss value: 64.39225
# Current loss value: 65.25576
# Current loss value: 66.038
# Current loss value: 66.79539
# Current loss value: 67.65229
# Current loss value: 68.413
# Current loss value: 69.19294
# Filter 1 processed in 1s
# Processing filter 2
# Current loss value: 0.0
# Filter 2 processed in 1s
# Processing filter 3
# Current loss value: 0.0
# Filter 3 processed in 1s
# Processing filter 4
# Current loss value: 0.0
# Filter 4 processed in 1s
# Processing filter 5
# Current loss value: 0.0
# Filter 5 processed in 1s
# Processing filter 6
# Current loss value: 0.0
# Filter 6 processed in 1s
# Processing filter 7
# Current loss value: 0.0
# Filter 7 processed in 1s
# Processing filter 8
# Current loss value: 0.0
# Filter 8 processed in 1s
# Processing filter 9
# Current loss value: 0.0
# Filter 9 processed in 1s
# Processing filter 10
# Current loss value: 0.0
# Filter 10 processed in 1s
# Processing filter 11
# Current loss value: 0.0
# Filter 11 processed in 1s
# Processing filter 12
# Current loss value: 0.0
# Filter 12 processed in 1s
# Processing filter 13
# Current loss value: 0.0
# Filter 13 processed in 1s
# Processing filter 14
# Current loss value: 0.0
# Filter 14 processed in 2s
# Processing filter 15
# Current loss value: 0.0
# Filter 15 processed in 1s
# Processing filter 16
# Current loss value: 0.0
# Filter 16 processed in 1s
# Processing filter 17
# Current loss value: 0.0
# Filter 17 processed in 1s
# Processing filter 18
# Current loss value: 0.0884998
# Current loss value: 0.39590934
# Current loss value: 0.70189697
# Current loss value: 1.0653696
# Current loss value: 1.5000716
# Current loss value: 2.1699674
# Current loss value: 2.8789392
# Current loss value: 3.5955403
# Current loss value: 4.4448047
# Current loss value: 5.3308806
# Current loss value: 6.2030272
# Current loss value: 7.1956096
# Current loss value: 8.285068
# Current loss value: 9.45952
# Current loss value: 10.71992
# Current loss value: 12.002054
# Current loss value: 13.436098
# Current loss value: 14.95654
# Current loss value: 16.492819
# Current loss value: 18.014284
# Filter 18 processed in 2s
# Processing filter 19
# Current loss value: 0.0
# Filter 19 processed in 1s
# Processing filter 20
# Current loss value: 0.82316214
# Current loss value: 0.9483712
# Current loss value: 1.1146849
# Current loss value: 1.3445708
# Current loss value: 1.6296891
# Current loss value: 1.9003803
# Current loss value: 2.1636677
# Current loss value: 2.4824052
# Current loss value: 2.871094
# Current loss value: 3.4999774
# Current loss value: 3.9865575
# Current loss value: 4.4751024
# Current loss value: 4.985796
# Current loss value: 5.560491
# Current loss value: 6.254428
# Current loss value: 7.0338874
# Current loss value: 7.8444695
# Current loss value: 8.585708
# Current loss value: 9.25115
# Current loss value: 9.807161
# Filter 20 processed in 2s
# Processing filter 21
# Current loss value: 0.0
# Filter 21 processed in 1s
# Processing filter 22
# Current loss value: 0.0
# Filter 22 processed in 2s
# Processing filter 23
# Current loss value: 0.00996673
# Current loss value: 0.052370206
# Current loss value: 0.07384638
# Current loss value: 0.105683506
# Current loss value: 0.13470192
# Current loss value: 0.114472464
# Current loss value: 0.13151343
# Current loss value: 0.15611559
# Current loss value: 0.15581642
# Current loss value: 0.1535007
# Current loss value: 0.15593657
# Current loss value: 0.18179305
# Current loss value: 0.1538351
# Current loss value: 0.18470451
# Current loss value: 0.20115842
# Current loss value: 0.2101334
# Current loss value: 0.20793901
# Current loss value: 0.21805793
# Current loss value: 0.23090436
# Current loss value: 0.2424265
# Filter 23 processed in 2s
# Processing filter 24
# Current loss value: 0.0
# Filter 24 processed in 2s
# Processing filter 25
# Current loss value: 0.0
# Filter 25 processed in 2s
# Processing filter 26
# Current loss value: 0.0
# Filter 26 processed in 2s
# Processing filter 27
# Current loss value: 0.0
# Filter 27 processed in 2s
# Processing filter 28
# Current loss value: 0.0
# Filter 28 processed in 2s
# Processing filter 29
# Current loss value: 0.0
# Filter 29 processed in 2s
# Processing filter 30
# Current loss value: 1.1217364
# Current loss value: 1.2193469
# Current loss value: 1.399344
# Current loss value: 1.5255182
# Current loss value: 1.6711998
# Current loss value: 1.848315
# Current loss value: 2.0036442
# Current loss value: 2.195977
# Current loss value: 2.3000824
# Current loss value: 2.5067303
# Current loss value: 2.7091258
# Current loss value: 2.8001807
# Current loss value: 2.9040346
# Current loss value: 3.0553322
# Current loss value: 3.1754243
# Current loss value: 3.320445
# Current loss value: 3.5379493
# Current loss value: 3.7149596
# Current loss value: 3.9278212
# Current loss value: 4.1440563
# Filter 30 processed in 2s
# Processing filter 31
# Current loss value: 0.0
# Filter 31 processed in 2s
# Processing filter 32
# Current loss value: 0.0
# Filter 32 processed in 2s
# Processing filter 33
# Current loss value: 0.0
# Filter 33 processed in 2s
# Processing filter 34
# Current loss value: 0.0
# Filter 34 processed in 2s
# Processing filter 35
# Current loss value: 0.0
# Filter 35 processed in 2s
# Processing filter 36
# Current loss value: 1.0066612
# Current loss value: 1.8428442
# Current loss value: 4.0520115
# Current loss value: 6.4269867
# Current loss value: 9.09869
# Current loss value: 11.749622
# Current loss value: 14.351816
# Current loss value: 17.064798
# Current loss value: 19.911272
# Current loss value: 22.738829
# Current loss value: 25.73017
# Current loss value: 28.800705
# Current loss value: 31.997597
# Current loss value: 35.22603
# Current loss value: 38.658115
# Current loss value: 42.18588
# Current loss value: 45.820766
# Current loss value: 49.65206
# Current loss value: 53.56194
# Current loss value: 57.606655
# Filter 36 processed in 2s
# Processing filter 37
# Current loss value: 0.0
# Filter 37 processed in 2s
# Processing filter 38
# Current loss value: 0.0
# Filter 38 processed in 2s
# Processing filter 39
# Current loss value: 0.0
# Filter 39 processed in 2s
# Processing filter 40
# Current loss value: 0.30080804
# Current loss value: 0.6858595
# Current loss value: 1.2437301
# Current loss value: 1.968456
# Current loss value: 2.8935745
# Current loss value: 4.073693
# Current loss value: 5.238248
# Current loss value: 6.425542
# Current loss value: 7.723909
# Current loss value: 9.169594
# Current loss value: 10.627427
# Current loss value: 12.095535
# Current loss value: 13.932189
# Current loss value: 16.063766
# Current loss value: 18.739708
# Current loss value: 21.63654
# Current loss value: 24.911394
# Current loss value: 28.293995
# Current loss value: 31.85266
# Current loss value: 35.52893
# Filter 40 processed in 2s
# Processing filter 41
# Current loss value: 0.0
# Filter 41 processed in 2s
# Processing filter 42
# Current loss value: 0.0
# Filter 42 processed in 2s
# Processing filter 43
# Current loss value: 0.0
# Filter 43 processed in 2s
# Processing filter 44
# Current loss value: 0.0
# Filter 44 processed in 2s
# Processing filter 45
# Current loss value: 0.15785879
# Current loss value: 0.41601285
# Current loss value: 0.7835029
# Current loss value: 1.1347526
# Current loss value: 1.450472
# Current loss value: 1.8281295
# Current loss value: 2.2639596
# Current loss value: 2.8606894
# Current loss value: 3.6191866
# Current loss value: 4.395459
# Current loss value: 5.0587697
# Current loss value: 5.7326975
# Current loss value: 6.8949003
# Current loss value: 8.257579
# Current loss value: 9.562
# Current loss value: 10.789637
# Current loss value: 12.15879
# Current loss value: 13.366768
# Current loss value: 14.61373
# Current loss value: 15.98465
# Filter 45 processed in 2s
# Processing filter 46
# Current loss value: 0.0
# Filter 46 processed in 2s
# Processing filter 47
# Current loss value: 0.37268627
# Current loss value: 0.564522
# Current loss value: 0.862181
# Current loss value: 1.0900637
# Current loss value: 1.3236257
# Current loss value: 1.5908628
# Current loss value: 2.0263882
# Current loss value: 2.6537118
# Current loss value: 3.4687908
# Current loss value: 4.3999076
# Current loss value: 5.4064755
# Current loss value: 6.6308303
# Current loss value: 7.9167857
# Current loss value: 9.236943
# Current loss value: 10.662829
# Current loss value: 12.254648
# Current loss value: 13.929834
# Current loss value: 15.614104
# Current loss value: 17.247013
# Current loss value: 18.90775
# Filter 47 processed in 2s
# Processing filter 48
# Current loss value: 0.0
# Filter 48 processed in 2s
# Processing filter 49
# Current loss value: 0.0
# Filter 49 processed in 2s
# Processing filter 50
# Current loss value: 0.0
# Filter 50 processed in 2s
# Processing filter 51
# Current loss value: 0.080354325
# Current loss value: 0.17346616
# Current loss value: 0.23828034
# Current loss value: 0.30227393
# Current loss value: 0.3933458
# Current loss value: 0.5743357
# Current loss value: 0.81394225
# Current loss value: 1.0023403
# Current loss value: 1.1309731
# Current loss value: 1.2434956
# Current loss value: 1.3657126
# Current loss value: 1.4437654
# Current loss value: 1.5474287
# Current loss value: 1.6841319
# Current loss value: 1.8202734
# Current loss value: 1.8284726
# Current loss value: 1.9861478
# Current loss value: 2.164051
# Current loss value: 2.205696
# Current loss value: 2.3276358
# Filter 51 processed in 2s
# Processing filter 52
# Current loss value: 0.09225625
# Current loss value: 0.14450109
# Current loss value: 0.3123176
# Current loss value: 0.45557612
# Current loss value: 0.5566871
# Current loss value: 0.62163615
# Current loss value: 0.8415484
# Current loss value: 1.0098146
# Current loss value: 1.1267852
# Current loss value: 1.3821008
# Current loss value: 1.594506
# Current loss value: 1.8332529
# Current loss value: 1.9938898
# Current loss value: 2.1813004
# Current loss value: 2.316605
# Current loss value: 2.425483
# Current loss value: 2.577525
# Current loss value: 2.7193625
# Current loss value: 2.9648209
# Current loss value: 3.1125698
# Filter 52 processed in 2s
# Processing filter 53
# Current loss value: 49.74184
# Current loss value: 54.703537
# Current loss value: 55.78617
# Current loss value: 57.267067
# Current loss value: 58.703827
# Current loss value: 60.226078
# Current loss value: 61.852043
# Current loss value: 63.855038
# Current loss value: 66.10229
# Current loss value: 68.44787
# Current loss value: 70.82049
# Current loss value: 73.28422
# Current loss value: 75.76288
# Current loss value: 78.46978
# Current loss value: 81.254265
# Current loss value: 84.14939
# Current loss value: 87.11157
# Current loss value: 90.26111
# Current loss value: 93.41247
# Current loss value: 96.64447
# Filter 53 processed in 2s
# Processing filter 54
# Current loss value: 0.0
# Filter 54 processed in 2s
# Processing filter 55
# Current loss value: 0.0
# Filter 55 processed in 2s
# Processing filter 56
# Current loss value: 0.0008938626
# Current loss value: 0.019937897
# Current loss value: 0.05641785
# Current loss value: 0.09451106
# Current loss value: 0.11964748
# Current loss value: 0.12646995
# Current loss value: 0.14845099
# Current loss value: 0.1656702
# Current loss value: 0.16753803
# Current loss value: 0.18705857
# Current loss value: 0.21165705
# Current loss value: 0.23511368
# Current loss value: 0.24345312
# Current loss value: 0.2949352
# Current loss value: 0.33238414
# Current loss value: 0.35264766
# Current loss value: 0.39185002
# Current loss value: 0.41589198
# Current loss value: 0.4654603
# Current loss value: 0.49731877
# Filter 56 processed in 2s
# Processing filter 57
# Current loss value: 0.0
# Filter 57 processed in 2s
# Processing filter 58
# Current loss value: 0.0
# Filter 58 processed in 2s
# Processing filter 59
# Current loss value: 0.0
# Filter 59 processed in 2s
# Processing filter 60
# Current loss value: 0.0
# Filter 60 processed in 2s
# Processing filter 61
# Current loss value: 0.0
# Filter 61 processed in 2s
# Processing filter 62
# Current loss value: 0.15905133
# Current loss value: 0.25644565
# Current loss value: 0.29505783
# Current loss value: 0.3596889
# Current loss value: 0.36563045
# Current loss value: 0.39200968
# Current loss value: 0.41559067
# Current loss value: 0.42201182
# Current loss value: 0.4596645
# Current loss value: 0.48161098
# Current loss value: 0.49924624
# Current loss value: 0.52606183
# Current loss value: 0.5436746
# Current loss value: 0.5618039
# Current loss value: 0.5894765
# Current loss value: 0.60259074
# Current loss value: 0.62500983
# Current loss value: 0.6355237
# Current loss value: 0.662663
# Current loss value: 0.67350596
# Filter 62 processed in 2s
# Processing filter 63
# Current loss value: 0.0
# Filter 63 processed in 2s
# Processing filter 64
# Current loss value: 0.0
# Filter 64 processed in 2s
# Processing filter 65
# Current loss value: 0.0
# Filter 65 processed in 2s
# Processing filter 66
# Current loss value: 0.0
# Filter 66 processed in 2s
# Processing filter 67
# Current loss value: 0.0
# Filter 67 processed in 2s
# Processing filter 68
# Current loss value: 0.16670042
# Current loss value: 0.42725942
# Current loss value: 0.76789325
# Current loss value: 2.22605
# Current loss value: 3.8167462
# Current loss value: 5.6458535
# Current loss value: 7.513692
# Current loss value: 9.363291
# Current loss value: 11.382083
# Current loss value: 13.411599
# Current loss value: 15.405042
# Current loss value: 17.475056
# Current loss value: 19.497786
# Current loss value: 21.796968
# Current loss value: 24.03125
# Current loss value: 26.308847
# Current loss value: 28.498913
# Current loss value: 30.845207
# Current loss value: 33.47899
# Current loss value: 36.211494
# Filter 68 processed in 2s
# Processing filter 69
# Current loss value: 0.0
# Filter 69 processed in 2s
# Processing filter 70
# Current loss value: 0.0
# Filter 70 processed in 2s
# Processing filter 71
# Current loss value: 0.0
# Filter 71 processed in 2s
# Processing filter 72
# Current loss value: 0.0
# Filter 72 processed in 2s
# Processing filter 73
# Current loss value: 0.0
# Filter 73 processed in 2s
# Processing filter 74
# Current loss value: 0.0
# Filter 74 processed in 2s
# Processing filter 75
# Current loss value: 0.0
# Filter 75 processed in 2s
# Processing filter 76
# Current loss value: 0.0
# Filter 76 processed in 2s
# Processing filter 77
# Current loss value: 0.0
# Filter 77 processed in 2s
# Processing filter 78
# Current loss value: 0.0
# Filter 78 processed in 2s
# Processing filter 79
# Current loss value: 0.0
# Filter 79 processed in 2s
# Processing filter 80
# Current loss value: 0.0
# Filter 80 processed in 2s
# Processing filter 81
# Current loss value: 0.0
# Filter 81 processed in 2s
# Processing filter 82
# Current loss value: 0.0
# Filter 82 processed in 2s
# Processing filter 83
# Current loss value: 0.0
# Filter 83 processed in 2s
# Processing filter 84
# Current loss value: 0.0
# Filter 84 processed in 2s
# Processing filter 85
# Current loss value: 0.0
# Filter 85 processed in 2s
# Processing filter 86
# Current loss value: 0.0
# Filter 86 processed in 2s
# Processing filter 87
# Current loss value: 0.0
# Filter 87 processed in 2s
# Processing filter 88
# Current loss value: 0.0
# Filter 88 processed in 2s
# Processing filter 89
# Current loss value: 0.10830168
# Current loss value: 0.27287912
# Current loss value: 0.42599505
# Current loss value: 0.68872434
# Current loss value: 0.9753454
# Current loss value: 1.162134
# Current loss value: 1.4446847
# Current loss value: 1.7099582
# Current loss value: 2.0258083
# Current loss value: 2.3809478
# Current loss value: 2.7792017
# Current loss value: 3.2752328
# Current loss value: 3.784662
# Current loss value: 4.3392215
# Current loss value: 4.9022326
# Current loss value: 5.47897
# Current loss value: 6.1257715
# Current loss value: 6.8085775
# Current loss value: 7.559987
# Current loss value: 8.334268
# Filter 89 processed in 2s
# Processing filter 90
# Current loss value: 0.0
# Filter 90 processed in 2s
# Processing filter 91
# Current loss value: 0.0
# Filter 91 processed in 2s
# Processing filter 92
# Current loss value: 0.0
# Filter 92 processed in 2s
# Processing filter 93
# Current loss value: 0.0
# Filter 93 processed in 2s
# Processing filter 94
# Current loss value: 0.0
# Filter 94 processed in 2s
# Processing filter 95
# Current loss value: 0.0
# Filter 95 processed in 2s
# Processing filter 96
# Current loss value: 0.0
# Filter 96 processed in 2s
# Processing filter 97
# Current loss value: 0.0
# Filter 97 processed in 2s
# Processing filter 98
# Current loss value: 0.0
# Filter 98 processed in 2s
# Processing filter 99
# Current loss value: 0.0
# Filter 99 processed in 2s
# Processing filter 100
# Current loss value: 0.0
# Filter 100 processed in 2s
# Processing filter 101
# Current loss value: 0.0
# Filter 101 processed in 2s
# Processing filter 102
# Current loss value: 0.0
# Filter 102 processed in 2s
# Processing filter 103
# Current loss value: 0.0
# Filter 103 processed in 2s
# Processing filter 104
# Current loss value: 0.0
# Filter 104 processed in 2s
# Processing filter 105
# Current loss value: 0.030974215
# Current loss value: 0.82181597
# Current loss value: 3.3498015
# Current loss value: 6.921454
# Current loss value: 11.439254
# Current loss value: 16.908726
# Current loss value: 23.199753
# Current loss value: 30.062265
# Current loss value: 37.487255
# Current loss value: 45.90686
# Current loss value: 57.175274
# Current loss value: 68.58938
# Current loss value: 79.7863
# Current loss value: 91.25081
# Current loss value: 103.21855
# Current loss value: 115.22895
# Current loss value: 127.90518
# Current loss value: 140.72638
# Current loss value: 153.97636
# Current loss value: 167.6522
# Filter 105 processed in 2s
# Processing filter 106
# Current loss value: 0.09692772
# Current loss value: 0.30756423
# Current loss value: 1.1709723
# Current loss value: 2.2647398
# Current loss value: 3.4463372
# Current loss value: 4.512317
# Current loss value: 5.420326
# Current loss value: 6.342837
# Current loss value: 7.398619
# Current loss value: 8.682004
# Current loss value: 9.904553
# Current loss value: 11.261113
# Current loss value: 15.438541
# Current loss value: 20.291449
# Current loss value: 24.816904
# Current loss value: 29.423065
# Current loss value: 34.12144
# Current loss value: 38.796165
# Current loss value: 43.58461
# Current loss value: 48.089817
# Filter 106 processed in 3s
# Processing filter 107
# Current loss value: 0.0
# Filter 107 processed in 2s
# Processing filter 108
# Current loss value: 0.0
# Filter 108 processed in 2s
# Processing filter 109
# Current loss value: 0.0
# Filter 109 processed in 2s
# Processing filter 110
# Current loss value: 0.0
# Filter 110 processed in 2s
# Processing filter 111
# Current loss value: 0.0
# Filter 111 processed in 2s
# Processing filter 112
# Current loss value: 0.71039754
# Current loss value: 0.78848267
# Current loss value: 0.8608471
# Current loss value: 0.935378
# Current loss value: 1.0273567
# Current loss value: 1.0982254
# Current loss value: 1.1771497
# Current loss value: 1.2250632
# Current loss value: 1.2891713
# Current loss value: 1.3562992
# Current loss value: 1.4136069
# Current loss value: 1.4870455
# Current loss value: 1.5655142
# Current loss value: 1.6983529
# Current loss value: 1.854894
# Current loss value: 1.950646
# Current loss value: 2.0284927
# Current loss value: 2.1241941
# Current loss value: 2.1557655
# Current loss value: 2.2752626
# Filter 112 processed in 2s
# Processing filter 113
# Current loss value: 0.32054654
# Current loss value: 0.4154503
# Current loss value: 0.53364277
# Current loss value: 0.6596227
# Current loss value: 0.84887236
# Current loss value: 0.9779537
# Current loss value: 1.2029921
# Current loss value: 1.4185809
# Current loss value: 1.5371829
# Current loss value: 1.6569633
# Current loss value: 1.8120607
# Current loss value: 1.8621707
# Current loss value: 2.0848083
# Current loss value: 2.3884013
# Current loss value: 3.3006694
# Current loss value: 4.04215
# Current loss value: 4.5830965
# Current loss value: 5.0503836
# Current loss value: 5.6228914
# Current loss value: 6.469499
# Filter 113 processed in 2s
# Processing filter 114
# Current loss value: 0.0
# Filter 114 processed in 2s
# Processing filter 115
# Current loss value: 0.0
# Filter 115 processed in 2s
# Processing filter 116
# Current loss value: 0.0
# Filter 116 processed in 2s
# Processing filter 117
# Current loss value: 0.0
# Filter 117 processed in 2s
# Processing filter 118
# Current loss value: 0.0
# Filter 118 processed in 2s
# Processing filter 119
# Current loss value: 0.0
# Filter 119 processed in 2s
# Processing filter 120
# Current loss value: 0.0
# Filter 120 processed in 2s
# Processing filter 121
# Current loss value: 0.0
# Filter 121 processed in 2s
# Processing filter 122
# Current loss value: 0.0
# Filter 122 processed in 2s
# Processing filter 123
# Current loss value: 0.0
# Filter 123 processed in 2s
# Processing filter 124
# Current loss value: 0.0
# Filter 124 processed in 2s
# Processing filter 125
# Current loss value: 36.260117
# Current loss value: 44.50879
# Current loss value: 48.83286
# Current loss value: 53.25509
# Current loss value: 56.766563
# Current loss value: 60.111477
# Current loss value: 63.394993
# Current loss value: 65.98558
# Current loss value: 68.357315
# Current loss value: 70.57566
# Current loss value: 72.58707
# Current loss value: 74.43738
# Current loss value: 76.27737
# Current loss value: 78.10017
# Current loss value: 79.8724
# Current loss value: 81.59518
# Current loss value: 83.260796
# Current loss value: 84.92713
# Current loss value: 86.43239
# Current loss value: 87.92464
# Filter 125 processed in 3s
# Processing filter 126
# Current loss value: 0.0
# Filter 126 processed in 2s
# Processing filter 127
# Current loss value: 0.0
# Filter 127 processed in 2s
# Processing filter 128
# Current loss value: 0.21802336
# Current loss value: 0.29160896
# Current loss value: 0.4149187
# Current loss value: 0.5197654
# Current loss value: 0.5794202
# Current loss value: 0.6297971
# Current loss value: 0.6872161
# Current loss value: 0.7426712
# Current loss value: 0.7969723
# Current loss value: 0.8535519
# Current loss value: 0.91690946
# Current loss value: 0.9991013
# Current loss value: 1.0784062
# Current loss value: 1.1579664
# Current loss value: 1.2291001
# Current loss value: 1.2677197
# Current loss value: 1.3357795
# Current loss value: 1.4231225
# Current loss value: 1.5199889
# Current loss value: 1.6571878
# Filter 128 processed in 3s
# Processing filter 129
# Current loss value: 0.0
# Filter 129 processed in 3s
# Processing filter 130
# Current loss value: 0.0
# Filter 130 processed in 3s
# Processing filter 131
# Current loss value: 0.0
# Filter 131 processed in 3s
# Processing filter 132
# Current loss value: 0.0
# Filter 132 processed in 3s
# Processing filter 133
# Current loss value: 0.0
# Filter 133 processed in 3s
# Processing filter 134
# Current loss value: 0.0
# Filter 134 processed in 3s
# Processing filter 135
# Current loss value: 0.0
# Filter 135 processed in 3s
# Processing filter 136
# Current loss value: 0.0
# Filter 136 processed in 3s
# Processing filter 137
# Current loss value: 0.0
# Filter 137 processed in 3s
# Processing filter 138
# Current loss value: 0.0
# Filter 138 processed in 3s
# Processing filter 139
# Current loss value: 0.8268569
# Current loss value: 0.8982334
# Current loss value: 0.99367434
# Current loss value: 1.091987
# Current loss value: 1.1891589
# Current loss value: 1.2766049
# Current loss value: 1.4570445
# Current loss value: 1.6590742
# Current loss value: 1.9662341
# Current loss value: 2.3477347
# Current loss value: 2.6810782
# Current loss value: 3.1618624
# Current loss value: 3.6696792
# Current loss value: 4.232957
# Current loss value: 4.887835
# Current loss value: 5.595573
# Current loss value: 6.296667
# Current loss value: 6.995709
# Current loss value: 7.704915
# Current loss value: 8.433745
# Filter 139 processed in 3s
# Processing filter 140
# Current loss value: 0.0
# Filter 140 processed in 3s
# Processing filter 141
# Current loss value: 0.1154383
# Current loss value: 0.18887192
# Current loss value: 0.2795839
# Current loss value: 0.32712963
# Current loss value: 0.34344527
# Current loss value: 0.38879246
# Current loss value: 0.4938915
# Current loss value: 0.6166421
# Current loss value: 0.71633214
# Current loss value: 0.8327831
# Current loss value: 0.90843177
# Current loss value: 1.025196
# Current loss value: 1.1233759
# Current loss value: 1.2380266
# Current loss value: 1.3329215
# Current loss value: 1.4351904
# Current loss value: 1.5361189
# Current loss value: 1.6001887
# Current loss value: 1.6586987
# Current loss value: 1.7539527
# Filter 141 processed in 3s
# Processing filter 142
# Current loss value: 0.0
# Filter 142 processed in 3s
# Processing filter 143
# Current loss value: 0.0
# Filter 143 processed in 3s
# Processing filter 144
# Current loss value: 0.0
# Filter 144 processed in 3s
# Processing filter 145
# Current loss value: 0.0
# Filter 145 processed in 3s
# Processing filter 146
# Current loss value: 0.0
# Filter 146 processed in 3s
# Processing filter 147
# Current loss value: 0.0
# Filter 147 processed in 3s
# Processing filter 148
# Current loss value: 0.0
# Filter 148 processed in 3s
# Processing filter 149
# Current loss value: 0.0
# Filter 149 processed in 3s
# Processing filter 150
# Current loss value: 0.0
# Filter 150 processed in 3s
# Processing filter 151
# Current loss value: 0.0
# Filter 151 processed in 3s
# Processing filter 152
# Current loss value: 0.23213518
# Current loss value: 0.49795756
# Current loss value: 0.7783
# Current loss value: 1.22388
# Current loss value: 1.5160228
# Current loss value: 1.7525736
# Current loss value: 2.0955393
# Current loss value: 2.3974123
# Current loss value: 2.6514795
# Current loss value: 2.8194263
# Current loss value: 3.319806
# Current loss value: 3.7059307
# Current loss value: 4.1198554
# Current loss value: 4.6475115
# Current loss value: 5.670093
# Current loss value: 6.618862
# Current loss value: 7.544584
# Current loss value: 8.483674
# Current loss value: 9.452461
# Current loss value: 10.664866
# Filter 152 processed in 3s
# Processing filter 153
# Current loss value: 0.24140227
# Current loss value: 0.38030574
# Current loss value: 0.4532208
# Current loss value: 0.62732685
# Current loss value: 0.7529103
# Current loss value: 0.9196887
# Current loss value: 1.1655765
# Current loss value: 1.4396598
# Current loss value: 1.673767
# Current loss value: 1.8929485
# Current loss value: 2.1615322
# Current loss value: 2.5007021
# Current loss value: 3.0438118
# Current loss value: 3.6963162
# Current loss value: 4.3671455
# Current loss value: 5.047177
# Current loss value: 5.7687316
# Current loss value: 6.519431
# Current loss value: 7.3039694
# Current loss value: 8.123797
# Filter 153 processed in 3s
# Processing filter 154
# Current loss value: 0.0
# Filter 154 processed in 3s
# Processing filter 155
# Current loss value: 0.0
# Filter 155 processed in 3s
# Processing filter 156
# Current loss value: 0.0
# Filter 156 processed in 3s
# Processing filter 157
# Current loss value: 0.0
# Filter 157 processed in 3s
# Processing filter 158
# Current loss value: 0.0
# Filter 158 processed in 3s
# Processing filter 159
# Current loss value: 0.0
# Filter 159 processed in 3s
# Processing filter 160
# Current loss value: 0.0
# Filter 160 processed in 3s
# Processing filter 161
# Current loss value: 0.0
# Filter 161 processed in 3s
# Processing filter 162
# Current loss value: 0.080159575
# Current loss value: 0.13987212
# Current loss value: 0.20562367
# Current loss value: 0.18380238
# Current loss value: 0.25590792
# Current loss value: 0.24514659
# Current loss value: 0.29291508
# Current loss value: 0.31652772
# Current loss value: 0.33046868
# Current loss value: 0.36082152
# Current loss value: 0.3552882
# Current loss value: 0.40261862
# Current loss value: 0.4078411
# Current loss value: 0.45388955
# Current loss value: 0.46192202
# Current loss value: 0.5027519
# Current loss value: 0.5158615
# Current loss value: 0.5509608
# Current loss value: 0.6115062
# Current loss value: 0.69905454
# Filter 162 processed in 3s
# Processing filter 163
# Current loss value: 3.2040927
# Current loss value: 7.81001
# Current loss value: 8.702098
# Current loss value: 7.8525414
# Current loss value: 8.639057
# Current loss value: 7.6828866
# Current loss value: 8.065762
# Current loss value: 8.854934
# Current loss value: 8.21543
# Current loss value: 8.6317005
# Current loss value: 8.232913
# Current loss value: 8.313027
# Current loss value: 8.625085
# Current loss value: 8.412567
# Current loss value: 7.984667
# Current loss value: 8.483519
# Current loss value: 7.8191905
# Current loss value: 8.450129
# Current loss value: 8.156779
# Current loss value: 8.408208
# Filter 163 processed in 3s
# Processing filter 164
# Current loss value: 0.0
# Filter 164 processed in 3s
# Processing filter 165
# Current loss value: 0.0
# Filter 165 processed in 3s
# Processing filter 166
# Current loss value: 0.0
# Filter 166 processed in 3s
# Processing filter 167
# Current loss value: 0.0
# Filter 167 processed in 3s
# Processing filter 168
# Current loss value: 0.0
# Filter 168 processed in 3s
# Processing filter 169
# Current loss value: 0.0
# Filter 169 processed in 3s
# Processing filter 170
# Current loss value: 0.0
# Filter 170 processed in 3s
# Processing filter 171
# Current loss value: 0.0
# Filter 171 processed in 3s
# Processing filter 172
# Current loss value: 0.0
# Filter 172 processed in 3s
# Processing filter 173
# Current loss value: 0.0
# Filter 173 processed in 3s
# Processing filter 174
# Current loss value: 0.0
# Filter 174 processed in 3s
# Processing filter 175
# Current loss value: 0.0
# Filter 175 processed in 3s
# Processing filter 176
# Current loss value: 0.0
# Filter 176 processed in 3s
# Processing filter 177
# Current loss value: 0.78247994
# Current loss value: 1.047821
# Current loss value: 1.2808553
# Current loss value: 1.6901205
# Current loss value: 2.1761186
# Current loss value: 2.7275233
# Current loss value: 3.4052763
# Current loss value: 4.155292
# Current loss value: 5.49355
# Current loss value: 8.212257
# Current loss value: 11.492324
# Current loss value: 15.218937
# Current loss value: 18.887848
# Current loss value: 22.86505
# Current loss value: 27.098562
# Current loss value: 31.514381
# Current loss value: 36.098415
# Current loss value: 40.815514
# Current loss value: 46.250793
# Current loss value: 51.934338
# Filter 177 processed in 3s
# Processing filter 178
# Current loss value: 0.0
# Filter 178 processed in 3s
# Processing filter 179
# Current loss value: 0.0
# Filter 179 processed in 3s
# Processing filter 180
# Current loss value: 0.0
# Filter 180 processed in 3s
# Processing filter 181
# Current loss value: 0.0
# Filter 181 processed in 3s
# Processing filter 182
# Current loss value: 0.0
# Filter 182 processed in 3s
# Processing filter 183
# Current loss value: 0.0
# Filter 183 processed in 3s
# Processing filter 184
# Current loss value: 0.0
# Filter 184 processed in 3s
# Processing filter 185
# Current loss value: 0.0
# Filter 185 processed in 3s
# Processing filter 186
# Current loss value: 0.0
# Filter 186 processed in 3s
# Processing filter 187
# Current loss value: 0.0
# Filter 187 processed in 3s
# Processing filter 188
# Current loss value: 0.0
# Filter 188 processed in 3s
# Processing filter 189
# Current loss value: 0.0
# Filter 189 processed in 3s
# Processing filter 190
# Current loss value: 0.0
# Filter 190 processed in 3s
# Processing filter 191
# Current loss value: 0.0
# Filter 191 processed in 3s
# Processing filter 192
# Current loss value: 0.0
# Filter 192 processed in 3s
# Processing filter 193
# Current loss value: 0.37098038
# Current loss value: 0.4575609
# Current loss value: 0.60596794
# Current loss value: 0.8848923
# Current loss value: 1.7146301
# Current loss value: 2.5300424
# Current loss value: 3.663287
# Current loss value: 5.2074237
# Current loss value: 6.856649
# Current loss value: 8.452766
# Current loss value: 10.20787
# Current loss value: 12.222332
# Current loss value: 14.469838
# Current loss value: 16.995102
# Current loss value: 19.500841
# Current loss value: 21.955307
# Current loss value: 24.496956
# Current loss value: 27.137938
# Current loss value: 29.941668
# Current loss value: 32.73272
# Filter 193 processed in 3s
# Processing filter 194
# Current loss value: 0.0
# Filter 194 processed in 3s
# Processing filter 195
# Current loss value: 0.0
# Filter 195 processed in 3s
# Processing filter 196
# Current loss value: 0.0
# Filter 196 processed in 3s
# Processing filter 197
# Current loss value: 0.0
# Filter 197 processed in 3s
# Processing filter 198
# Current loss value: 0.19402759
# Current loss value: 0.3752212
# Current loss value: 0.58535737
# Current loss value: 0.9507779
# Current loss value: 1.4435883
# Current loss value: 1.9807454
# Current loss value: 2.4450028
# Current loss value: 2.9717479
# Current loss value: 3.5748043
# Current loss value: 4.18012
# Current loss value: 4.9996834
# Current loss value: 5.9380093
# Current loss value: 6.8259296
# Current loss value: 7.852251
# Current loss value: 8.795316
# Current loss value: 9.877296
# Current loss value: 10.865176
# Current loss value: 11.895789
# Current loss value: 12.9839735
# Current loss value: 14.113206
# Filter 198 processed in 4s
# Processing filter 199
# Current loss value: 0.0
# Filter 199 processed in 4s

# %%
len(kept_filters)
# Out:
# 32

# %%
kept_filters[1][0].reshape(128,128)
# Out:
# (128, 128, 1)

# %%
plt.imshow(kept_filters[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-e4263c2ce89c> in <module>
# ----> 1 plt.imshow(kept_filters[0])
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2700         resample=resample, url=url, **({"data": data} if data is not
# -> 2701         None else {}), **kwargs)
#    2702     sci(__ret)
#    2703     return __ret
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5492                               resample=resample, **kwargs)
#    5493
# -> 5494         im.set_data(X)
#    5495         im.set_alpha(alpha)
#    5496         if im.get_clip_path() is None:
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     640         if (self._A.dtype != np.uint8 and
#     641                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 642             raise TypeError("Image data cannot be converted to float")
#     643
#     644         if not (self._A.ndim == 2
#
# TypeError: Image data cannot be converted to float

# %%
from keras.preprocessing.image import save_img
import matplotlib.pyplot as plt

# we will stich the best 64 filters on a 8 x 8 grid.
n = 2

# the filters that have the highest loss are assumed to be better-looking.
# we will only keep the top 64 filters.
kept_filters.sort(key=lambda x: x[1], reverse=True)
kept_filters = kept_filters[:n * n]

# build a black picture with enough space for
# our 8 x 8 filters of size 128 x 128, with a 5px margin in between
margin = 5
width = n * img_width + (n - 1) * margin
height = n * img_height + (n - 1) * margin
stitched_filters = np.zeros((width, height, 3))

# fill the picture with our saved filters
for i in range(n):
    for j in range(n):
        img, loss = kept_filters[i * n + j]
        width_margin = (img_width + margin) * i
        height_margin = (img_height + margin) * j
        stitched_filters[
            width_margin: width_margin + img_width,
            height_margin: height_margin + img_height, :] = img
        
        

# save the result to disk
save_img('stitched_filters_%dx%d_%s.png' % (n, n, layer_name), stitched_filters)
# Out:
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
